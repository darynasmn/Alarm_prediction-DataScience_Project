# %%
import pandas as pd

# %%
df_weather = pd.read_csv('raw_csv/all_weather_by_hour_v2.csv')

# %%
df_weather.head()
# Out:
#    city_latitude  city_longitude           city_resolvedAddress
# 0        50.7469         25.3263  Луцьк, Луцький район, Україна  \
# 1        50.7469         25.3263  Луцьк, Луцький район, Україна
# 2        50.7469         25.3263  Луцьк, Луцький район, Україна
# 3        50.7469         25.3263  Луцьк, Луцький район, Україна
# 4        50.7469         25.3263  Луцьк, Луцький район, Україна
#
#     city_address city_timezone  city_tzoffset day_datetime  day_datetimeEpoch
# 0  Lutsk,Ukraine   Europe/Kiev            2.0   2022-02-24         1645653600  \
# 1  Lutsk,Ukraine   Europe/Kiev            2.0   2022-02-24         1645653600
# 2  Lutsk,Ukraine   Europe/Kiev            2.0   2022-02-24         1645653600
# 3  Lutsk,Ukraine   Europe/Kiev            2.0   2022-02-24         1645653600
# 4  Lutsk,Ukraine   Europe/Kiev            2.0   2022-02-24         1645653600
#
#    day_tempmax  day_tempmin  ...  hour_visibility  hour_cloudcover
# ...

# %%
df_weather
# Out:
#         city_latitude  city_longitude           city_resolvedAddress
# 0             50.7469         25.3263  Луцьк, Луцький район, Україна  \
# 1             50.7469         25.3263  Луцьк, Луцький район, Україна
# 2             50.7469         25.3263  Луцьк, Луцький район, Україна
# 3             50.7469         25.3263  Луцьк, Луцький район, Україна
# 4             50.7469         25.3263  Луцьк, Луцький район, Україна
# ...               ...             ...                            ...
# 182707        49.2336         28.4486               Вінниця, Україна
# 182708        49.2336         28.4486               Вінниця, Україна
# 182709        49.2336         28.4486               Вінниця, Україна
# 182710        49.2336         28.4486               Вінниця, Україна
# 182711        49.2336         28.4486               Вінниця, Україна
#
#              city_address city_timezone  city_tzoffset day_datetime
# 0           Lutsk,Ukraine   Europe/Kiev            2.0   2022-02-24  \
# ...

# %%
df_weather.loc[:, 'day_tempmax'].unique()
# Out:
# array([  4.9,   6.3,   2.5,   3.4,   1.6,   2.2,   4.1,   2. ,   1.1,
#          1.3,   0.8,   0.6,  -1.3,   3.9,   3.3,   6. ,  11.5,   9.1,
#          6.4,   9.9,  13.1,  17.7,  17.8,  10.2,  13. ,  14.6,   6.6,
#         17.4,  13.7,  11. ,   7.1,   5.1,   3.2,   4.8,   5.9,  12.5,
#         19.3,  12.9,  15.6,   8.6,   9.2,  13.8,  16.2,  19.1,   9.7,
#          8.3,   5.7,   7. ,   8.5,   8.8,   8. ,  10.4,  16.5,  18.7,
#         13.2,  14.2,  14.9,  15.1,  17.9,  19.7,  16. ,  21.2,  19.8,
#         22.1,  17.5,  18.6,  22.9,  28.4,  21.3,  16.7,  18.9,  15.3,
#         21.6,  26.4,  21.5,  13.6,  21.1,  23.7,  20.7,  19.9,  16.3,
#         17.6,  20.5,  24.2,  22. ,  23.8,  21.8,  24.7,  27. ,  28.7,
#         29.1,  29.3,  26. ,  25.1,  27.3,  20. ,  22.6,  24. ,  30.2,
#         31.6,  23. ,  26.5,  27.6,  28.2,  29.7,  31.9,  33.4,  33.6,
#         31.2,  30.3,  25. ,  30.6,  22.5,  23.3,  22.2,  20.6,  19.6,
# ...

# %%
for x in range(df_weather.shape[0]):
    if df_weather.loc[x, "day_tempmax"] == 60.4:
        df_weather.loc[x, "day_tempmax"] = 30.2

# %%
df_weather.loc[106385, "day_tempmax"]
# Out:
# 30.2

# %%
df_weather.describe()
# Out:
#        city_latitude  city_longitude  city_tzoffset  day_datetimeEpoch
# count  182712.000000   182712.000000       182712.0       1.827120e+05  \
# mean       49.143234       30.142516            2.0       1.659910e+09
# std         1.337213        4.303979            0.0       8.255620e+06
# min        46.472500       22.285140            2.0       1.645654e+09
# 25%        48.292400       25.935500            2.0       1.652735e+09
# 50%        49.416800       30.737100            2.0       1.659906e+09
# 75%        50.253600       34.551700            2.0       1.667077e+09
# max        51.493700       37.814500            2.0       1.674166e+09
#
#          day_tempmax    day_tempmin       day_temp  day_feelslikemax
# count  182712.000000  182712.000000  182712.000000     182712.000000  \
# mean       15.399761       6.862514      11.090437         14.597199
# std         9.903808       7.814018       8.715009         10.771928
# ...

# %%
df_weather = df_weather.drop(['city_latitude', 'city_longitude', 'city_tzoffset', 'day_datetimeEpoch'], axis = 1)

# %%
df_weather.head()
# Out:
#             city_resolvedAddress   city_address city_timezone day_datetime
# 0  Луцьк, Луцький район, Україна  Lutsk,Ukraine   Europe/Kiev   2022-02-24  \
# 1  Луцьк, Луцький район, Україна  Lutsk,Ukraine   Europe/Kiev   2022-02-24
# 2  Луцьк, Луцький район, Україна  Lutsk,Ukraine   Europe/Kiev   2022-02-24
# 3  Луцьк, Луцький район, Україна  Lutsk,Ukraine   Europe/Kiev   2022-02-24
# 4  Луцьк, Луцький район, Україна  Lutsk,Ukraine   Europe/Kiev   2022-02-24
#
#    day_tempmax  day_tempmin  day_temp  day_feelslikemax  day_feelslikemin
# 0          4.9          0.7       2.6               4.0              -3.1  \
# 1          4.9          0.7       2.6               4.0              -3.1
# 2          4.9          0.7       2.6               4.0              -3.1
# 3          4.9          0.7       2.6               4.0              -3.1
# 4          4.9          0.7       2.6               4.0              -3.1
#
# ...

# %%
df_weather.columns
# Out:
# Index(['city_resolvedAddress', 'city_address', 'city_timezone', 'day_datetime',
#        'day_tempmax', 'day_tempmin', 'day_temp', 'day_feelslikemax',
#        'day_feelslikemin', 'day_feelslike', 'day_dew', 'day_humidity',
#        'day_precip', 'day_precipprob', 'day_precipcover', 'day_snow',
#        'day_snowdepth', 'day_windgust', 'day_windspeed', 'day_winddir',
#        'day_pressure', 'day_cloudcover', 'day_visibility',
#        'day_solarradiation', 'day_solarenergy', 'day_uvindex',
#        'day_severerisk', 'day_sunrise', 'day_sunriseEpoch', 'day_sunset',
#        'day_sunsetEpoch', 'day_moonphase', 'day_conditions', 'day_description',
#        'day_icon', 'day_source', 'day_preciptype', 'day_stations',
#        'hour_datetime', 'hour_datetimeEpoch', 'hour_temp', 'hour_feelslike',
#        'hour_humidity', 'hour_dew', 'hour_precip', 'hour_precipprob',
#        'hour_snow', 'hour_snowdepth', 'hour_preciptype', 'hour_windgust',
# ...

# %%
df_weather = df_weather.drop(['day_sunsetEpoch', "day_sunriseEpoch", "day_moonphase", "hour_stations", 'hour_source'], axis = 1)

# %%
df_weather.tail()
# Out:
#        city_resolvedAddress       city_address city_timezone day_datetime
# 182707     Вінниця, Україна  Vinnytsia,Ukraine   Europe/Kiev   2023-01-20  \
# 182708     Вінниця, Україна  Vinnytsia,Ukraine   Europe/Kiev   2023-01-20
# 182709     Вінниця, Україна  Vinnytsia,Ukraine   Europe/Kiev   2023-01-20
# 182710     Вінниця, Україна  Vinnytsia,Ukraine   Europe/Kiev   2023-01-20
# 182711     Вінниця, Україна  Vinnytsia,Ukraine   Europe/Kiev   2023-01-20
#
#         day_tempmax  day_tempmin  day_temp  day_feelslikemax
# 182707         11.2          5.7       7.9              11.2  \
# 182708         11.2          5.7       7.9              11.2
# 182709         11.2          5.7       7.9              11.2
# 182710         11.2          5.7       7.9              11.2
# 182711         11.2          5.7       7.9              11.2
#
#         day_feelslikemin  day_feelslike  ...  hour_winddir  hour_pressure
# 182707               3.9            6.7  ...         122.1         1010.0  \
# ...

# %%
OUTPUT_FOLDER = "prepared_csv"
WEATHER_EVENTS_OUTPUT_DATA_FILE = "all_hourly_weather_events.csv"
df_weather.to_csv(f"{OUTPUT_FOLDER}/{WEATHER_EVENTS_OUTPUT_DATA_FILE}", sep=";", index=False)
